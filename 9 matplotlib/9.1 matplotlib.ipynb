# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot(np.arange(10))
# Out:
# <img src="data:image/png;base64,..." width="468">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="424">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,4)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(),'c--')

# %%
fig, axes = plt .subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d09eb38>,
# ...
#       dtype=object)

# %%
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[0,1]

# %%
fig , axes = plt.subplots(2,2,sharex = True ,sharey = True)
for i in range(2):
    for j  in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50 , color='c', alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(),'co--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(randn(30).cumsum(),color='m',linestyle='dashed',marker='o')

# %%
data = np.random.randn(30).cumsum()

# %%
data
# Out:
# array([ 0.57406044,  1.66996293,  1.21179403,  0.3894728 , -1.9043918 ,
#        -1.75444829, -1.19177732, -1.01312706, -0.60080398,  0.21373249,
#        -0.08926851, -0.52746985, -0.97517956, -2.13947461,  1.37892752,
#         1.41715875,  1.17220511,  1.95747153,  2.27856297,  2.48825138,
#         2.7736321 ,  3.10120925,  1.24556998,  1.65040133,  1.17005627,
#         1.56805396,  0.75659429,  1.14350477,  0.54579228,  1.26584241])

# %%
plt.plot(data,'c--',label='Default')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')

# %%
plt.legend(loc='best')

# %% [markdown]
# ### 9.1.3 刻度 标签 图标

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="646">

# %%
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ax.title= 'title'

# %%
fig = plt.figure()
bx = fig.add_subplot(1,1,1)
bx.plot(np.random.randn(100).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bx.set_title('title')
# Out:
# Text(0.5,1,'title')

# %%
bx.set_xticks([0,25,50,75,100])

# %%
bx.set_xticklabels(['cusa','cusb','cusc','cusd','cuse'],rotation=20,fontsize='small')
# Out:
# [Text(0,0,'cusa'),
#  Text(25,0,'cusb'),
#  Text(50,0,'cusc'),
#  Text(75,0,'cusd'),
#  Text(100,0,'cuse')]

# %%
bx.set_xlabel('x axis')
# Out:
# Text(0.5,47.0444,'x axis')

# %%
bx.set_ylabel('y axis')
# Out:
# Text(88.5694,0.5,'y axis')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(randn(1000).cumsum(),'k-',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')

# %%
ax.legend(loc='best')  #添加图例

# %%
ax.legend(loc=0)

# %%
ax.legend?

# %%
ax.text(500,32,'test text',family='monospace',fontsize=10,color='red')
# Out:
# Text(500,32,'test text')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(10))
plt.show()

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1,1,1)

# %%
rect = plt.Rectangle((2,6),4,2,color='k',alpha=0.5)

# %%
ax.add_patch(rect)

# %%
ax.plot(np.random.randn(200).cumsum())

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(100).cumsum())
